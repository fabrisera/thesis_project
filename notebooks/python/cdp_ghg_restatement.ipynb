# %% [markdown]
# `Restatement postponed: you need to ask more to better understand what restatement is and how to work with it`

# %%
import pandas as pd
import seaborn as sns
import numpy as np

# %%
restatement = pd.read_stata("../../data/CDP Cleaning/cleaned outputs/cdp_ghg_restatement.dta")

# %%
restatement
# Out:
#            id  scope  accounting_year  reporting_year        ghg1  \
# 0          44    1.0           2021.0          2022.0     167.800
# 1          44    1.0           2020.0          2021.0     117.700
# 2          44    1.0           2020.0          2022.0     117.700
# 3          44    1.0           2019.0          2020.0     151.157
# 4          44    1.0           2019.0          2022.0     150.500
# ...       ...    ...              ...             ...         ...
# 85193  895909    2.0           2021.0          2022.0         NaN
# 85194  896044    1.0           2021.0          2022.0  963327.000
# 85195  896044    2.0           2021.0          2022.0         NaN
# 85196  896120    1.0           2021.0          2022.0    3308.000
# 85197  896123    1.0           2021.0          2022.0       0.000
#
#        ghg2_location  ghg2_market  ghg2  \
# 0                NaN          NaN   NaN
# 1                NaN          NaN   NaN
# 2                NaN          NaN   NaN
# ...

# %%
restatement.isna().mean()
# Out:
# id                     0.000000
# scope                  0.000000
# accounting_year        0.000000
# reporting_year         0.000000
# ghg1                   0.486021
# ghg2_location          0.663901
# ghg2_market            0.809773
# ghg2                   0.875983
# comment                0.000000
# ghg1_restatement       0.910350
# ghg1_change            0.910350
# ghg2loc_restatement    0.925597
# ghg2loc_change         0.927416
# ghg2mkt_restatement    0.958098
# ghg2mkt_change         0.960727
# ghg2_restatement       0.991995
# ghg2_change            0.993497
# dtype: float64

# %%
sns.distplot(restatement['ghg1_restatement'])
# Out:
# /var/folders/z7/jmcsyl9x47zdw6n1xd2_16jh0000gn/T/ipykernel_18497/4140763843.py:1: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(restatement['ghg1_restatement'])
# <Axes: xlabel='ghg1_restatement', ylabel='Density'>

# %% [markdown]
# - Ideas: i can include indicator from this dataset on whether there has been a restatement or not. Would not go as far as including numerical predictor due to the large number of missing values.
# - I will have to ask about this

# %%
restatement.columns
# Out:
# Index(['id', 'scope', 'accounting_year', 'reporting_year', 'ghg1',
#        'ghg2_location', 'ghg2_market', 'ghg2', 'comment', 'ghg1_restatement',
#        'ghg1_change', 'ghg2loc_restatement', 'ghg2loc_change',
#        'ghg2mkt_restatement', 'ghg2mkt_change', 'ghg2_restatement',
#        'ghg2_change'],
#       dtype='object')
