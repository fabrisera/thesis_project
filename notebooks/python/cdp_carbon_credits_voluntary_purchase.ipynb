# %% [markdown]
# `This file is redundant, I will not process it`

# %%
import pandas as pd
import seaborn as sns
import numpy as np

# %%
# read the file into a dataframe
df = pd.read_stata('../../data/CDP Cleaning/cleaned outputs/cdp_carbon_credits_voluntary_purchase.dta')
df.shape
# Out:
# (3646, 20)

# %%
df.head()
# Out:
#    id    year  cdp_num_credits  cdp_num_credits_riskadj  \
# 0  53  2015.0            41.00                    41.00
# 1  53  2016.0            40.00                    40.00
# 2  79  2021.0         20140.00                     0.00
# 3  79  2022.0         20438.00                 20438.00
# 4  97  2017.0             3.56                     3.56
#
#    cdp_carbon_credit_purchase_n  cdp_cc_cancelled  cdp_cc_cancelled_adj  \
# 0                           1.0              41.0                  41.0
# 1                           1.0              40.0                  40.0
# 2                           3.0           20140.0                   0.0
# 3                           5.0           20438.0               20438.0
# 4                           1.0               0.0                   0.0
#
#    cdp_cc_cancelled_n  cdp_cc_not_cancelled  cdp_cc_not_cancelled_adj  \
# 0                 1.0                   0.0                       0.0
# ...

# %%
df_2 = pd.read_stata('../../data/CDP Cleaning/cleaned outputs/cdp_carbon_credits_full.dta')

# %%
df_2.head()
# Out:
#    id    year               Q1                                Q2  \
# 0  53  2015.0  credit purchase                    biomass energy
# 1  53  2016.0  credit purchase                    biomass energy
# 2  64  2014.0  credit purchase  other: emission credit brokerage
# 3  79  2021.0  credit purchase                           forests
# 4  79  2021.0  credit purchase                              wind
#
#                                Q4       Q5  Q6   Q7                    Q8  \
# 0  vcs (verified carbon standard)       41  41  yes  voluntary offsetting
# 1  vcs (verified carbon standard)       40  40  yes  voluntary offsetting
# 2                not yet verified        3   0  yes            compliance
# 3                   gold standard    366.0      yes  voluntary offsetting
# 4                   gold standard  18492.0      yes  voluntary offsetting
#
#   cdp_orig_or_purchase_clean cdp_proj_type_clean  \
# 0            credit purchase      biomass energy
# ...

# %% [markdown]
# I believe that the voluntary purchase file is a working file and therefore just by using the carbon credits full I should have all the relevant information already without needing to perform extra work.
