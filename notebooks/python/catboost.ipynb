# %%
import pandas as pd
import numpy as np
import catboost as cb
from catboost import Pool, CatBoostRegressor, cv

# %%
data = pd.read_csv('../R/final_model_predictions.csv')

# %%
data.drop(['Unnamed: 0'], axis=1, inplace=True)

# %%
data.drop(columns=['Companyname', 'Gind', 'Isin', 'Ghg.Change.Real.Cat.Next'], inplace=True)

# %%
# make a list of columns that have text data with a loop (note object columns can also be numbers)
text_columns = []
for col in data.columns:
    if data[col].dtype == 'object':
        text_columns.append(col)

# %%
text_columns
# Out:
# ['Country', 'Continent', 'Industry', 'Method.Ind', 'Type.Scope1']

# %%
train_set = data.loc[data['Year'] < 9]
validation_set = data.loc[data['Year'] == 9]
test_set = data.loc[data['Year'] == 10]

# %%
continuous_features = [col for col in data.columns if col not in ['Id', 'Year', 'Ghg.Change.Real.Next', 'Industry', 'Country', 'Continent', 'Method.Ind', 'Type.Scope1'] and data[col].nunique() > 2]
binary_features = [col for col in data.columns if data[col].nunique() == 2]
train_stats = train_set[continuous_features].agg(['mean', 'std'])

# %%
# Function to standardize data (excluding binary features)
def standardize_data(df, stats, continuous_features, binary_features):
    standardized_df = df.copy()
    for feature in continuous_features:
        if feature not in binary_features:  # Only standardize continuous features
            mean = stats.loc['mean', feature]
            std = stats.loc['std', feature]
            standardized_df[feature] = (df[feature] - mean) / std
    # Replace NaN values resulted from standardization with 0 (especially for features with no variance)
    standardized_df = standardized_df.fillna(0)
    return standardized_df


# Standardize the entire dataset based on statistics from the first 10 years
df_standardized = standardize_data(data, train_stats, continuous_features, binary_features)


  # Last year for testing

# Now, you can proceed to create sequences from train_data_standardized and test_data_standardized
# Remember, for LSTM, sequences should be shaped properly according to your model's requirements.

# %%
categorical_features = ['Id', 'Industry', 'Country', 'Continent', 'Method.Ind', 'Type.Scope1']

# %%
# re split df_standardized into train, validation, and test sets
train_set = df_standardized.loc[df_standardized['Year'] < 9]
validation_set = df_standardized.loc[df_standardized['Year'] == 9]
test_set = df_standardized.loc[df_standardized['Year'] == 10]

# %%
X_train = train_set.drop(columns=['Ghg.Change.Real.Next'])
y_train = train_set['Ghg.Change.Real.Next']
X_val = validation_set.drop(columns=['Ghg.Change.Real.Next'])
y_val = validation_set['Ghg.Change.Real.Next']
X_test = test_set.drop(columns=['Ghg.Change.Real.Next'])
y_test = test_set['Ghg.Change.Real.Next']

# %%
# find the index of elements in categorical_features in X_train.columns
categorical_features_indices = [X_train.columns.get_loc(col) for col in categorical_features if col in X_train]

# %%
# Assuming you have your training, validation, and test datasets as follows:
# X_train, y_train for training data
# X_validation, y_validation for validation data
# X_test, y_test for test data

# Initialize data pools
train_pool = Pool(X_train, y_train, cat_features=categorical_features_indices)
validation_pool = Pool(X_val, y_val, cat_features=categorical_features_indices)

# Specify model parameters
model_params = {
    'iterations': 1000,
    'learning_rate': 0.03,
    'depth': 6,
    'loss_function': 'RMSE',  # You can change this according to your problem
    'eval_metric': 'RMSE',    # Evaluation metric, change if necessary
    'random_seed': 42,
    'logging_level': 'Verbose',  # You can change this to 'Silent' for less output
}

# Initialize CatBoostRegressor model
model = CatBoostRegressor(**model_params)

# Train model
model.fit(train_pool, eval_set=validation_pool, early_stopping_rounds=50)

# Make predictions
predictions = model.predict(X_test)

# Evaluate the model
from sklearn.metrics import mean_squared_error

mse = mean_squared_error(y_test, predictions)
print(f"Test MSE: {mse}")
# Out:
# 0:	learn: 6.9839955	test: 10.4262051	best: 10.4262051 (0)	total: 22.8ms	remaining: 22.8s
# 1:	learn: 6.9653003	test: 10.3979004	best: 10.3979004 (1)	total: 31.6ms	remaining: 15.8s
# 2:	learn: 6.9462056	test: 10.3698569	best: 10.3698569 (2)	total: 41.7ms	remaining: 13.9s
# 3:	learn: 6.9290715	test: 10.3444704	best: 10.3444704 (3)	total: 50.8ms	remaining: 12.6s
# 4:	learn: 6.9116229	test: 10.3116043	best: 10.3116043 (4)	total: 58ms	remaining: 11.5s
# 5:	learn: 6.8950141	test: 10.2804955	best: 10.2804955 (5)	total: 64.4ms	remaining: 10.7s
# 6:	learn: 6.8794180	test: 10.2589154	best: 10.2589154 (6)	total: 78.3ms	remaining: 11.1s
# 7:	learn: 6.8645219	test: 10.2372027	best: 10.2372027 (7)	total: 84.9ms	remaining: 10.5s
# 8:	learn: 6.8468316	test: 10.2080995	best: 10.2080995 (8)	total: 91.1ms	remaining: 10s
# 9:	learn: 6.8324623	test: 10.1869758	best: 10.1869758 (9)	total: 97.3ms	remaining: 9.63s
# 10:	learn: 6.8205248	test: 10.1688278	best: 10.1688278 (10)	total: 105ms	remaining: 9.44s
# 11:	learn: 6.8074725	test: 10.1487804	best: 10.1487804 (11)	total: 111ms	remaining: 9.13s
# 12:	learn: 6.7946120	test: 10.1275584	best: 10.1275584 (12)	total: 118ms	remaining: 8.93s
# 13:	learn: 6.7803587	test: 10.1050653	best: 10.1050653 (13)	total: 124ms	remaining: 8.73s
# 14:	learn: 6.7682806	test: 10.0845802	best: 10.0845802 (14)	total: 130ms	remaining: 8.53s
# 15:	learn: 6.7569045	test: 10.0664522	best: 10.0664522 (15)	total: 136ms	remaining: 8.34s
# 16:	learn: 6.7476633	test: 10.0548262	best: 10.0548262 (16)	total: 142ms	remaining: 8.23s
# 17:	learn: 6.7364430	test: 10.0381172	best: 10.0381172 (17)	total: 148ms	remaining: 8.08s
# 18:	learn: 6.7267877	test: 10.0215585	best: 10.0215585 (18)	total: 154ms	remaining: 7.94s
# 19:	learn: 6.7165742	test: 10.0009417	best: 10.0009417 (19)	total: 161ms	remaining: 7.87s
# 20:	learn: 6.7079172	test: 9.9868460	best: 9.9868460 (20)	total: 166ms	remaining: 7.75s
# 21:	learn: 6.6985663	test: 9.9698804	best: 9.9698804 (21)	total: 173ms	remaining: 7.7s
# 22:	learn: 6.6891336	test: 9.9521005	best: 9.9521005 (22)	total: 179ms	remaining: 7.6s
# 23:	learn: 6.6804806	test: 9.9405394	best: 9.9405394 (23)	total: 185ms	remaining: 7.51s
# 24:	learn: 6.6662963	test: 9.9257049	best: 9.9257049 (24)	total: 191ms	remaining: 7.45s
# 25:	learn: 6.6583870	test: 9.9115379	best: 9.9115379 (25)	total: 198ms	remaining: 7.41s
# 26:	learn: 6.6474980	test: 9.9054499	best: 9.9054499 (26)	total: 204ms	remaining: 7.34s
# 315:	learn: 6.0687791	test: 9.5293394	best: 9.5261087 (288)	total: 2.15s	remaining: 4.66s
# 316:	learn: 6.0671753	test: 9.5298312	best: 9.5261087 (288)	total: 2.16s	remaining: 4.65s
# 317:	learn: 6.0644162	test: 9.5327317	best: 9.5261087 (288)	total: 2.16s	remaining: 4.64s
# 318:	learn: 6.0641211	test: 9.5325625	best: 9.5261087 (288)	total: 2.17s	remaining: 4.63s
# 319:	learn: 6.0632548	test: 9.5333713	best: 9.5261087 (288)	total: 2.18s	remaining: 4.63s
# 320:	learn: 6.0614906	test: 9.5328702	best: 9.5261087 (288)	total: 2.19s	remaining: 4.63s
# 321:	learn: 6.0602868	test: 9.5332743	best: 9.5261087 (288)	total: 2.2s	remaining: 4.63s
# 322:	learn: 6.0578238	test: 9.5327576	best: 9.5261087 (288)	total: 2.21s	remaining: 4.63s
# 323:	learn: 6.0569700	test: 9.5326686	best: 9.5261087 (288)	total: 2.21s	remaining: 4.62s
# 324:	learn: 6.0558531	test: 9.5325047	best: 9.5261087 (288)	total: 2.22s	remaining: 4.62s
# 325:	learn: 6.0549670	test: 9.5322453	best: 9.5261087 (288)	total: 2.23s	remaining: 4.61s
# 326:	learn: 6.0542244	test: 9.5333284	best: 9.5261087 (288)	total: 2.24s	remaining: 4.61s
# 327:	learn: 6.0521538	test: 9.5327547	best: 9.5261087 (288)	total: 2.25s	remaining: 4.61s
# 328:	learn: 6.0497692	test: 9.5330905	best: 9.5261087 (288)	total: 2.26s	remaining: 4.61s
# 329:	learn: 6.0486558	test: 9.5329249	best: 9.5261087 (288)	total: 2.26s	remaining: 4.6s
# 330:	learn: 6.0481274	test: 9.5325760	best: 9.5261087 (288)	total: 2.27s	remaining: 4.59s
# 331:	learn: 6.0479454	test: 9.5324774	best: 9.5261087 (288)	total: 2.27s	remaining: 4.58s
# 332:	learn: 6.0472528	test: 9.5324834	best: 9.5261087 (288)	total: 2.28s	remaining: 4.57s
# 333:	learn: 6.0464826	test: 9.5326168	best: 9.5261087 (288)	total: 2.29s	remaining: 4.56s
# 334:	learn: 6.0444741	test: 9.5334583	best: 9.5261087 (288)	total: 2.29s	remaining: 4.55s
# 335:	learn: 6.0433246	test: 9.5338320	best: 9.5261087 (288)	total: 2.3s	remaining: 4.54s
# 336:	learn: 6.0415435	test: 9.5337898	best: 9.5261087 (288)	total: 2.3s	remaining: 4.53s
# 337:	learn: 6.0389629	test: 9.5330824	best: 9.5261087 (288)	total: 2.31s	remaining: 4.52s
# 338:	learn: 6.0375474	test: 9.5336507	best: 9.5261087 (288)	total: 2.31s	remaining: 4.51s
# Stopped by overfitting detector  (50 iterations wait)
#
# bestTest = 9.526108701
# bestIteration = 288
#
# Shrink model to first 289 iterations.
# Test MSE: 92.35891589368532

# %%
# test mae
from sklearn.metrics import mean_absolute_error
mae = mean_absolute_error(y_test, predictions)
print(f"Test MAE: {mae}")
# Out:
# Test MAE: 6.216770869852613

# %%
# test R2
from sklearn.metrics import r2_score
r2 = r2_score(y_test, predictions)
print(f"Test R2: {r2}")
# Out:
# Test R2: 0.09907985817544429

# %%
import numpy as np
from catboost import Pool, CatBoostRegressor
from sklearn.metrics import mean_squared_error

# Assuming you have your training, validation, and test datasets as follows:
# X_train, y_train for training data
# X_validation, y_validation for validation data
# And 'categorical_features_indices' is a list of categorical feature indices

train_pool = Pool(X_train, y_train, cat_features=categorical_features_indices)
validation_pool = Pool(X_val, y_val, cat_features=categorical_features_indices)

# Define parameter grid
param_grid = {
    'depth': [6, 8, 10],
    'iterations': [1000, 1500],
    'learning_rate': [0.005, 0.01],
    'l2_leaf_reg': [1, 3]
}

# %%
best_params = None
best_rmse = float('inf')

# Iterate over all combinations of parameters
for depth in param_grid['depth']:
    for iterations in param_grid['iterations']:
        for learning_rate in param_grid['learning_rate']:
            for l2_leaf_reg in param_grid['l2_leaf_reg']:
                # Define model with current set of parameters
                model = CatBoostRegressor(
                    depth=depth,
                    iterations=iterations,
                    learning_rate=learning_rate,
                    l2_leaf_reg=l2_leaf_reg,
                    loss_function='RMSE',
                    eval_metric='RMSE',
                    random_seed=42,
                    logging_level='Silent',
                    thread_count = 8  # Set to 'Verbose' to see training logs
                )
                
                # Train model on training dataset
                model.fit(train_pool)
                
                # Evaluate model on validation dataset
                predictions = model.predict(validation_pool)
                rmse = np.sqrt(mean_squared_error(y_val, predictions))
                
                # Update best parameters if current model is better
                if rmse < best_rmse:
                    best_rmse = rmse
                    best_params = {
                        'depth': depth,
                        'iterations': iterations,
                        'learning_rate': learning_rate,
                        'l2_leaf_reg': l2_leaf_reg
                    }

print(f"Best parameters: {best_params}")
print(f"Best RMSE on validation set: {best_rmse}")
# Out:
# Best parameters: {'depth': 8, 'iterations': 1000, 'learning_rate': 0.01, 'l2_leaf_reg': 1}
# Best RMSE on validation set: 9.496817592756415

# %%
# evaluate best model on test set
model = CatBoostRegressor(
    depth=best_params['depth'],
    iterations=best_params['iterations'],
    learning_rate=best_params['learning_rate'],
    l2_leaf_reg=best_params['l2_leaf_reg'],
    loss_function='RMSE',
    eval_metric='RMSE',
    random_seed=42,
    logging_level='Silent'
)

model.fit(train_pool)
predictions = model.predict(X_test)
rmse = np.sqrt(mean_squared_error(y_test, predictions))
print(f"RMSE on test set with best model: {rmse}")

# print r2
r2 = r2_score(y_test, predictions)
print(f"Test R2: {r2}")

# print mae
mae = mean_absolute_error(y_test, predictions)
print(f"Test MAE: {mae}")
# Out:
# RMSE on test set with best model: 9.584479554637436
# Test R2: 0.10392462930171409
# Test MAE: 6.188308086768396

# %%
# feature importance
feature_importance = model.get_feature_importance(train_pool)
feature_names = X_train.columns
for score, name in sorted(zip(feature_importance, feature_names), reverse=True):
    print('{}: {}'.format(name, score))
# Out:
# Ghg.Change.Real: 20.711285897218744
# Cdp.Targetamount.Mean: 5.942385736267044
# Id: 5.569923703139661
# Continent: 4.83317939208637
# Ghg2Market: 4.1007382525607206
# Industry: 3.710477388006951
# Ghg1: 2.896831359694945
# Type.Scope1: 2.52588862253826
# Country: 2.3357611819568542
# Cdp.Baseyear.Mean: 1.8534773394801574
# Ghg.Change.Total: 1.6921727588354905
# Net.Income.Over.Assets: 1.657066676248041
# Ghg.Int.Change: 1.623848793385911
# Ghg.Change.Output: 1.3941354534478079
# Cdp.Targetduration.Mean: 1.315955307172771
# Co2.Total.Log1P: 1.2909147660045894
# Roe: 1.2711661212396137
# Market.Cap: 1.2705103766821044
# Ghg2Location: 1.2363042504986095
# Investment.Total.Log1P: 1.2338784927047246
# Method.Ind: 1.1969292412804249
# Ghg.Int.Figure: 1.1636024864302972
# Tot.Assets: 1.095874762228697
# Ghg3.Count: 1.0344555182539434
# Employees: 1.024429039225645
# Year: 0.9872650819322244
# Cdp.Timeprogress.Mean: 0.9328851447346047
# Net.Income: 0.9231833327369626
# Ghg.Change.Measure: 0.9079269562943177
# Cdp.Targetscope.Percent.Mean: 0.8963980091972066
# Revenue: 0.8895822483734813
# Assets.1Y.Gr: 0.8771749425122306
# Ghg.Change.Nonzero.Count: 0.819670597461875
# Methane.Emissions: 0.8173472293127159
# Ghg3.Total: 0.7971093774970194
# Employees.1Y.Gr: 0.7628560589792337
# Co2.Counter: 0.7585972251979607
# Investment.Counter: 0.7422738785579012
# Cdp.Lowcarbon.Rev.Total: 0.7216560220639945
# Msaving.Total.Log1P: 0.7062139984880829
# Cdp.Baseyearemission.Mean: 0.7025187080686017
# Ghg.Change.Othergroup: 0.6936563179068455
# Cdp.Targettype.Absolute: 0.6924272069183505
# Ghg.Verification.Scope3.Yes: 0.686267480029878
# Initiative.Scope2: 0.6655117096290958
# Reporting.Boundary.Operational.Control: 0.5781387809657582
# Reporting.Boundary.Not.Reported: 0.506876862880003
# Ghg.Change.Structure: 0.4568633516109281
# Cdp.Num.Credits.Clean.Sum: 0.4312145588403817
# Cdp.Targettype.Intensity: 0.40948493878281494
# Cdp.Aggregated.Risk: 0.3963631652742604
# Method.Ind.Employee.Engagement: 0.38285726457951025
# Initiative.Scope3: 0.37419101955757733
# Absent.Cdp.Initiative.Firm.Year.Processed.Csv: 0.3697079197440398
# Initiative.Scope1: 0.36850877581477043
# Type.Scope1.Reasonable: 0.35043373508950143
# Msaving.Counter: 0.3372493448469156
# Cdp.Purpose.Clean.Voluntary.Offsetting: 0.2978904331067015
# Ghg.Change.Real.Cat: 0.2930872612049793
# Cdp.Aggregated.Opp: 0.2808915648087174
# Type.Scope1.Limited: 0.2737305327921241
# Cdp.Num.Credits.Riskadj.Clean.Sum: 0.260534197443888
# Cdp.Boardoversight.I: 0.23908047121087253
# Cdp.Risk.Transition: 0.2234444859192954
# Method.Ind.Other: 0.21467122234676436
# Reporting.Boundary.Financial.Control: 0.1848408374336687
# Cdp.Orig.Or.Purchase.Clean.Credit.Purchase: 0.18215793374472966
# Reporting.Boundary.Equity.Share: 0.1481713063926052
# Method.Ind.Macc: 0.14373731231612816
# Cdp.Credits.Cancelled.Clean.Yes: 0.1394871562386233
# Cdp.Num.Credits.Clean.Count: 0.1342085844331857
# Cdp.Risk.Physical: 0.13134060497009575
# Method.Ind.Internal.Incentives: 0.11866337333640521
# Cdp.Incentivebinary.I: 0.11275033983204084
# Method.Ind.Compliance: 0.10230170989610651
# Method.Ind.Internal.Finance: 0.10075809472041887
# Method.Ind.Gov.Partnership: 0.09284260324070162
# Absent.Cdp.Initative.Method.Processed.Csv: 0.09005757224160568
# Type.Scope1.N.A: 0.0854157123196978
# Cdp.Orig.Or.Purchase.Clean.Credit.Origination: 0.08176570394179543
# Method.Ind.Financial.Opt: 0.07429206377081525
# Ghg2Market.Na: 0.07275181539684927
# Ghg.Verification.Scope2.Yes: 0.07247292992066562
# Ghg.Verification.Scope1.Yes: 0.07236238734042469
# Absent.Cdp.Carbon.Credits.Full.Processed.Csv: 0.05956057649230293
# Cdp.Lowcarbon.Rev.Total.Missing: 0.0551763080931844
# Cdp.Num.Credits.Clean.Missing.Sum: 0.05017449710751528
# Cdp.Credits.Cancelled.Clean.Missing: 0.04894238114783902
# Cdp.Num.Credits.Riskadj.Clean.Missing.Sum: 0.045297981006867195
# Cdp.Credits.Cancelled.Clean.No: 0.04504441048787221
# Method.Ind.Internal.Price: 0.04389628591741782
# Type.Scope1.Third.Party.Underway: 0.04081832363467016
# Type.Scope1.Moderate: 0.0393251622482508
# Ghg.Verification.Scope3.No.Data: 0.035499444932972635
# Ghg1.Na: 0.03353581786921641
# Ghg.Verification.Scope1.No.Data: 0.03297308880833129
# Proportion.Verified.Scope2: 0.031032833947373585
# Method.Ind.Budget.Efficiency: 0.029167911219740772
# Proportion.Verified.Scope1: 0.02874366213119546
# Method.Ind.Lower.Roi: 0.027040542163582895
# Cdp.Purpose.Clean.Missing: 0.02700366899427979
# Ghg.Int.Figure.Na: 0.026385553666213847
# Cdp.Purpose.Clean.Other: 0.025885927167800662
# Cdp.Purpose.Clean.Compliance: 0.022879442121076714
# Method.Ind.Budget.Low.Carbon: 0.02103584142490726
# Cdp.Targetduration.Mean.Missing: 0.018021764074186535
# Absent.Cdp.Lowcarbon.Processed.Csv: 0.016592494600899864
# Absent.Cdp.Methane.Processed.Csv: 0.016244475038388776
# Absent.Cdp.Ghg.Verification.Frim.Year.Processed.Csv: 0.011847752416258323
# Cdp.Targetscope.Percent.Mean.Missing: 0.01085392920216364
# Absent.Cdp.Initiative.Processed.Csv: 0.003104740394852013
# Ghg.Verification.Scope2.No.Data: 0.00253344460389768
# Reporting.Boundary.Other: 0.0023444533607029842
# Cdp.Incentivebinary.I.Na: 0.0012922656223470698
# Absent.Cdp.Ghg.All.Scopes.Processed.Csv: 0.00043264931633970574
# Msaving.Total.Log1P.Missing: 0.0
# Investment.Total.Log1P.Missing: 0.0
# Ghg3.Total.Na: 0.0
# Ghg2Location.Na: 0.0
# Ghg.Int.Change.Na: 0.0
# Co2.Total.Log1P.Missing: 0.0
# Cdp.Timeprogress.Mean.Missing: 0.0
# Cdp.Targetamount.Mean.Missing: 0.0
# Cdp.Boardoversight.I.Na: 0.0
# Cdp.Baseyearemission.Mean.Missing: 0.0
# Cdp.Baseyear.Mean.Missing: 0.0
# Absent.Cdp.Target.Processed.Csv: 0.0
# Absent.Cdp.Summary.Selected.Processed.Csv: 0.0
# Absent.Cdp.Riskopp.Processed.Csv: 0.0
# Absent.Cdp.Incentives.Processed.Csv: 0.0
# Absent.Cdp.Ghg.Int.Processed.Csv: 0.0
# Absent.Cdp.Ghg.Change.Processed.Csv: 0.0
