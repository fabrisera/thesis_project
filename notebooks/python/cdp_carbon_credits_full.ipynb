# %% [markdown]
# `Carbon Credits - done, could reduce some columns`
#
# Predictors description:
# - Carbon credits are part of the C1.1.2 section of the CDP report
# - The main distinction is on whether a credit is originated or purchased, originated credits result from carbon savings initiatives, while purchases serve to reduce GHG footprint
#
# Main operations:
# - Conversion to firm-year: aggregated by id and year and created summary statistics (sum, count) for the numerical variables
# - for the categorical ones I one hot encoded them (without dropping the first category) and then I summed the ohe variables. In this way, if a company has two credits in a year belonging to that category, then that category would have an assigned value of two. Therefore, the final categorical columns are not binary, but count.
#
# Alternatives:
# - When I am dealing with origination and purchase, should I change the sign of the number of credits?
# - Note that some companies do not report the number of credits they purchase, in this case when aggregating with summary statistics the sum will equal zero.
# - Consider removing those columns: cdp_credits_cancelled_clean_missing	cdp_purpose_clean_compliance	cdp_purpose_clean_other	cdp_purpose_clean_voluntary offsetting	cdp_purpose_clean_missing if you want to reduce the dimensionality of the data
#
# Joining process with id, year, isin:
# - Not all companies have carbon credits reported, therefore when joining them it is important to prevent dropping rows.
# - To do so, in the joining process, an indicator on whether there are no carbon purchases shall be created, along with missing values corresponding to those rows

# %%
import pandas as pd
import seaborn as sns
import numpy as np

# %%
# read the file into a dataframe
df = pd.read_stata('../../data/CDP Cleaning/cleaned outputs/cdp_carbon_credits_full.dta')
df.shape
# Out:
# (15348, 16)

# %%
df.isna().sum()
# Out:
# id                                  0
# year                                0
# Q1                                  0
# Q2                                  0
# Q4                                  0
# Q5                                  0
# Q6                                  0
# Q7                                  0
# Q8                                  0
# cdp_orig_or_purchase_clean          0
# cdp_proj_type_clean                 0
# cdp_verification_clean              0
# cdp_num_credits_clean             669
# cdp_num_credits_riskadj_clean    3208
# cdp_credits_cancelled_clean         0
# cdp_purpose_clean                   0
# dtype: int64

# %%
df.groupby('year').count()
# Out:
#           id    Q1    Q2    Q4    Q5    Q6    Q7    Q8  \
# year
# 2010.0   619   619   619   619   619   619   619   619
# 2011.0   977   977   977   977   977   977   977   977
# 2012.0  1130  1130  1130  1130  1130  1130  1130  1130
# 2013.0  1350  1350  1350  1350  1350  1350  1350  1350
# 2014.0  1183  1183  1183  1183  1183  1183  1183  1183
# 2015.0  1054  1054  1054  1054  1054  1054  1054  1054
# 2016.0  1100  1100  1100  1100  1100  1100  1100  1100
# 2017.0  1010  1010  1010  1010  1010  1010  1010  1010
# 2018.0   997   997   997   997   997   997   997   997
# 2019.0   918   918   918   918   918   918   918   918
# 2020.0  1208  1208  1208  1208  1208  1208  1208  1208
# 2021.0  1616  1616  1616  1616  1616  1616  1616  1616
# 2022.0  2186  2186  2186  2186  2186  2186  2186  2186
#
#         cdp_orig_or_purchase_clean  cdp_proj_type_clean  \
# year
# 2010.0                         619                  619
# 2011.0                         977                  977
# 2012.0                        1130                 1130
# 2013.0                        1350                 1350
# 2014.0                        1183                 1183
# 2015.0                        1054                 1054
# 2016.0                        1100                 1100
# 2017.0                        1010                 1010
# 2018.0                         997                  997
# 2019.0                         918                  918
# 2020.0                        1208                 1208
# 2021.0                        1616                 1616
# 2022.0                        2186                 2186
#
#         cdp_verification_clean  cdp_num_credits_clean  \
# year
# 2010.0                     619                    539
# 2011.0                     977                    895
# 2012.0                    1130                   1052
# 2013.0                    1350                   1231
# 2014.0                    1183                   1113
# 2015.0                    1054                   1001
# 2016.0                    1100                   1065
# 2017.0                    1010                    978
# 2018.0                     997                    977
# 2019.0                     918                    907
# 2020.0                    1208                   1186
# 2021.0                    1616                   1598
# 2022.0                    2186                   2137
#
#         cdp_num_credits_riskadj_clean  cdp_credits_cancelled_clean  \
# year
# 2010.0                              0                          619
# 2011.0                            638                          977
# 2012.0                            782                         1130
# 2013.0                            957                         1350
# 2014.0                            951                         1183
# 2015.0                            840                         1054
# 2016.0                            938                         1100
# 2017.0                            847                         1010
# 2018.0                            847                          997
# 2019.0                            816                          918
# 2020.0                           1119                         1208
# 2021.0                           1490                         1616
# 2022.0                           1915                         2186
#
#         cdp_purpose_clean
# year
# 2010.0                619
# 2011.0                977
# 2012.0               1130
# 2013.0               1350
# 2014.0               1183
# 2015.0               1054
# 2016.0               1100
# 2017.0               1010
# 2018.0                997
# 2019.0                918
# 2020.0               1208
# 2021.0               1616
# 2022.0               2186

# %%
df.columns
# Out:
# Index(['id', 'year', 'Q1', 'Q2', 'Q4', 'Q5', 'Q6', 'Q7', 'Q8',
#        'cdp_orig_or_purchase_clean', 'cdp_proj_type_clean',
#        'cdp_verification_clean', 'cdp_num_credits_clean',
#        'cdp_num_credits_riskadj_clean', 'cdp_credits_cancelled_clean',
#        'cdp_purpose_clean'],
#       dtype='object')

# %%
# count number of unique id, year pairs
df.groupby(['id', 'year']).size().shape
# Out:
# (5784,)

# %% [markdown]
# `Multiple credit purchases per company`
# - on average a company purchases: 2.65 types of credits per year
# - there shall be an indicator that signals wheter a company has purchased credits or not

# %%
df.groupby(['id', 'year'])['year'].count().mean()
# Out:
# 2.6535269709543567

# %%
# are there any duplicates?
df[df.duplicated(['id', 'year'], keep=False)]
# Out:
#            id    year               Q1                                     Q2  \
# 3          79  2021.0  credit purchase                                forests
# 4          79  2021.0  credit purchase                                   wind
# 5          79  2021.0  credit purchase                         biomass energy
# 6          79  2022.0  credit purchase                                forests
# 7          79  2022.0  credit purchase                                forests
# ...       ...     ...              ...                                    ...
# 15341  895062  2022.0  credit purchase                              transport
# 15343  895218  2022.0  credit purchase                              co2 usage
# 15344  895218  2022.0  credit purchase                                forests
# 15345  895218  2022.0  credit purchase                                forests
# 15346  895218  2022.0  credit purchase  other, please specify: carbon removal
#
#                                                       Q4       Q5      Q6  \
# 3                                          gold standard    366.0
# 4                                          gold standard  18492.0
# 5                                          gold standard   1282.0     0.0
# 6                         vcs (verified carbon standard)   1380.0  1380.0
# 7                         vcs (verified carbon standard)   3620.0  3620.0
# ...                                                  ...      ...     ...
# 15341                     acr (american carbon registry)    803.0   803.0
# 15343                                      gold standard   2438.0  2438.0
# 15344  ccbs (developed by the climate, community and ...   4753.0  4753.0
# 15345                                      gold standard   1638.0  1638.0
# 15346                         other, please specify: dnv    185.0   185.0
#
#                  Q7                    Q8 cdp_orig_or_purchase_clean  \
# 3               yes  voluntary offsetting            credit purchase
# 4               yes  voluntary offsetting            credit purchase
# 5               yes  voluntary offsetting            credit purchase
# 6               yes  voluntary offsetting            credit purchase
# 7               yes  voluntary offsetting            credit purchase
# ...             ...                   ...                        ...
# 15341           yes  voluntary offsetting            credit purchase
# 15343  not relevant  voluntary offsetting            credit purchase
# 15344  not relevant  voluntary offsetting            credit purchase
# 15345  not relevant  voluntary offsetting            credit purchase
# 15346  not relevant  voluntary offsetting            credit purchase
#
#       cdp_proj_type_clean                             cdp_verification_clean  \
# 3                 forests                                      gold standard
# 4                    wind                                      gold standard
# 5          biomass energy                                      gold standard
# 6                 forests                     vcs (verified carbon standard)
# 7                 forests                     vcs (verified carbon standard)
# ...                   ...                                                ...
# 15341           transport                     acr (american carbon registry)
# 15343           co2 usage                                      gold standard
# 15344             forests  ccbs (developed by the climate, community and ...
# 15345             forests                                      gold standard
# 15346               other                                              other
#
#        cdp_num_credits_clean  cdp_num_credits_riskadj_clean  \
# 3                      366.0                            NaN
# 4                    18492.0                            NaN
# 5                     1282.0                            0.0
# 6                     1380.0                         1380.0
# 7                     3620.0                         3620.0
# ...                      ...                            ...
# 15341                  803.0                          803.0
# 15343                 2438.0                         2438.0
# 15344                 4753.0                         4753.0
# 15345                 1638.0                         1638.0
# 15346                  185.0                          185.0
#
#       cdp_credits_cancelled_clean     cdp_purpose_clean
# 3                             yes  voluntary offsetting
# 4                             yes  voluntary offsetting
# 5                             yes  voluntary offsetting
# 6                             yes  voluntary offsetting
# 7                             yes  voluntary offsetting
# ...                           ...                   ...
# 15341                         yes  voluntary offsetting
# 15343                              voluntary offsetting
# 15344                              voluntary offsetting
# 15345                              voluntary offsetting
# 15346                              voluntary offsetting
#
# [12090 rows x 16 columns]

# %%
# remove leading and trailing spaces from all values
df = df.apply(lambda x: x.str.strip() if x.dtype == "object" else x)

# %%
# if a value is an empty string, replace it with NaN
df = df.replace(r'^\s*$', pd.NA, regex=True)

# %% [markdown]
# Dropping Columns that are repeated (namely Q1, Q2, ...) given that they are already in the dataframe with proper names

# %%
df.drop(columns=['Q1', 'Q2', 'Q4', 'Q5', 'Q6', 'Q7', 'Q8'], inplace=True)

# %%
df.head()
# Out:
#    id    year cdp_orig_or_purchase_clean cdp_proj_type_clean  \
# 0  53  2015.0            credit purchase      biomass energy
# 1  53  2016.0            credit purchase      biomass energy
# 2  64  2014.0            credit purchase               other
# 3  79  2021.0            credit purchase             forests
# 4  79  2021.0            credit purchase                wind
#
#            cdp_verification_clean  cdp_num_credits_clean  \
# 0  vcs (verified carbon standard)                   41.0
# 1  vcs (verified carbon standard)                   40.0
# 2                not yet verified                    3.0
# 3                   gold standard                  366.0
# 4                   gold standard                18492.0
#
#    cdp_num_credits_riskadj_clean cdp_credits_cancelled_clean  \
# 0                           41.0                         yes
# 1                           40.0                         yes
# 2                            0.0                         yes
# 3                            NaN                         yes
# 4                            NaN                         yes
#
#       cdp_purpose_clean
# 0  voluntary offsetting
# 1  voluntary offsetting
# 2            compliance
# 3  voluntary offsetting
# 4  voluntary offsetting

# %%
# print the unique values for each column
for col in df.columns:
    print(col)
    print(df[col].unique())
    print('\n')
# Out:
# id
# [    53     64     79 ... 895100 895218 895519]
#
#
# year
# [2015. 2016. 2014. 2021. 2022. 2010. 2011. 2012. 2013. 2017. 2018. 2019.
#  2020.]
#
#
# cdp_orig_or_purchase_clean
# ['credit purchase' 'credit origination']
#
#
# cdp_proj_type_clean
# ['biomass energy' 'other' 'forests' 'wind' 'methane avoidance'
#  'landfill gas' <NA> 'energy efficiency' 'hydro' 'fossil fuel switch'
#  'cement' 'agriculture' 'n20' 'transport' 'co2 usage' 'coal mine/bed ch4'
#  'solar' 'energy distribution' 'fugitive' 'pfcs and sf6' 'hfcs' 'n2o'
#  'tidal']
#
#
# cdp_verification_clean
# ['vcs (verified carbon standard)' 'not yet verified' 'gold standard' <NA>
#  'cdm' 'cdm (clean development mechanism)' 'ji (joint implementation)'
#  'ccbs (developed by the climate, community and biodiversity alliance, ccba)'
#  'other' 'vcs' 'vcs (voluntary carbon standard)' 'ver+' 'car'
#  'emissions reduction fund of the australian government'
#  'ver+ (tÜv sÜd standard)' 'acr (american carbon registry)' 'plan vivo'
#  'ji' 'car (the climate action reserve)'
#  'ccbs - climate, community & biodiversity standards'
#  'ver+ (tv sd standard)']
#
#
# cdp_num_credits_clean
# [  41.   40.    3. ...  792.  803. 2438.]
#
#
# cdp_num_credits_riskadj_clean
# [  41.   40.    0. ...  803. 2438. 4753.]
#
#
# cdp_credits_cancelled_clean
# ['yes' <NA> 'no']
#
#
# cdp_purpose_clean
# ['voluntary offsetting' 'compliance' <NA> 'other']

# %%
# number of nas for each column
df.isna().sum()
# Out:
# id                                  0
# year                                0
# cdp_orig_or_purchase_clean          0
# cdp_proj_type_clean               711
# cdp_verification_clean            253
# cdp_num_credits_clean             669
# cdp_num_credits_riskadj_clean    3208
# cdp_credits_cancelled_clean      3417
# cdp_purpose_clean                 814
# dtype: int64

# %%
df.dtypes
# Out:
# id                                 int32
# year                             float32
# cdp_orig_or_purchase_clean        object
# cdp_proj_type_clean               object
# cdp_verification_clean            object
# cdp_num_credits_clean            float32
# cdp_num_credits_riskadj_clean    float32
# cdp_credits_cancelled_clean       object
# cdp_purpose_clean                 object
# dtype: object

# %%
# convert year to int
df['year'] = df['year'].astype('Int32')
df['id'] = df['id'].astype('Int32')

# convert all object columns to category
for col in df.columns:
    if df[col].dtype == 'object':
        df[col] = df[col].astype('category')

# %%
df.head()
# Out:
#    id  year cdp_orig_or_purchase_clean cdp_proj_type_clean  \
# 0  53  2015            credit purchase      biomass energy
# 1  53  2016            credit purchase      biomass energy
# 2  64  2014            credit purchase               other
# 3  79  2021            credit purchase             forests
# 4  79  2021            credit purchase                wind
#
#            cdp_verification_clean  cdp_num_credits_clean  \
# 0  vcs (verified carbon standard)                   41.0
# 1  vcs (verified carbon standard)                   40.0
# 2                not yet verified                    3.0
# 3                   gold standard                  366.0
# 4                   gold standard                18492.0
#
#    cdp_num_credits_riskadj_clean cdp_credits_cancelled_clean  \
# 0                           41.0                         yes
# 1                           40.0                         yes
# 2                            0.0                         yes
# 3                            NaN                         yes
# 4                            NaN                         yes
#
#       cdp_purpose_clean
# 0  voluntary offsetting
# 1  voluntary offsetting
# 2            compliance
# 3  voluntary offsetting
# 4  voluntary offsetting

# %%
df.dtypes
# Out:
# id                                  Int32
# year                                Int32
# cdp_orig_or_purchase_clean       category
# cdp_proj_type_clean              category
# cdp_verification_clean           category
# cdp_num_credits_clean             float32
# cdp_num_credits_riskadj_clean     float32
# cdp_credits_cancelled_clean      category
# cdp_purpose_clean                category
# dtype: object

# %%
summary = pd.DataFrame(df.dtypes)
summary['nuber unique'] = df.nunique()
summary['isna'] = df.isna().sum()

# %%
summary
# Out:
#                                       0  nuber unique  isna
# id                                Int32          1661     0
# year                              Int32            13     0
# cdp_orig_or_purchase_clean     category             2     0
# cdp_proj_type_clean            category            22   711
# cdp_verification_clean         category            20   253
# cdp_num_credits_clean           float32          7988   669
# cdp_num_credits_riskadj_clean   float32          6328  3208
# cdp_credits_cancelled_clean    category             2  3417
# cdp_purpose_clean              category             3   814

# %%
# for each category column, mark missing values as missing
for col in df.columns:
    if df[col].dtype.name == 'category':
        df[col] = df[col].cat.add_categories('missing')
        df[col].fillna('missing', inplace=True)

# %%
df
# Out:
#            id  year cdp_orig_or_purchase_clean cdp_proj_type_clean  \
# 0          53  2015            credit purchase      biomass energy
# 1          53  2016            credit purchase      biomass energy
# 2          64  2014            credit purchase               other
# 3          79  2021            credit purchase             forests
# 4          79  2021            credit purchase                wind
# ...       ...   ...                        ...                 ...
# 15343  895218  2022            credit purchase           co2 usage
# 15344  895218  2022            credit purchase             forests
# 15345  895218  2022            credit purchase             forests
# 15346  895218  2022            credit purchase               other
# 15347  895519  2022            credit purchase                wind
#
#                                   cdp_verification_clean  \
# 0                         vcs (verified carbon standard)
# 1                         vcs (verified carbon standard)
# 2                                       not yet verified
# 3                                          gold standard
# 4                                          gold standard
# ...                                                  ...
# 15343                                      gold standard
# 15344  ccbs (developed by the climate, community and ...
# 15345                                      gold standard
# 15346                                              other
# 15347                  cdm (clean development mechanism)
#
#        cdp_num_credits_clean  cdp_num_credits_riskadj_clean  \
# 0                       41.0                           41.0
# 1                       40.0                           40.0
# 2                        3.0                            0.0
# 3                      366.0                            NaN
# 4                    18492.0                            NaN
# ...                      ...                            ...
# 15343                 2438.0                         2438.0
# 15344                 4753.0                         4753.0
# 15345                 1638.0                         1638.0
# 15346                  185.0                          185.0
# 15347                70000.0                        70000.0
#
#       cdp_credits_cancelled_clean     cdp_purpose_clean
# 0                             yes  voluntary offsetting
# 1                             yes  voluntary offsetting
# 2                             yes            compliance
# 3                             yes  voluntary offsetting
# 4                             yes  voluntary offsetting
# ...                           ...                   ...
# 15343                     missing  voluntary offsetting
# 15344                     missing  voluntary offsetting
# 15345                     missing  voluntary offsetting
# 15346                     missing  voluntary offsetting
# 15347                         yes  voluntary offsetting
#
# [15348 rows x 9 columns]

# %%
# for each float32 column, mark missing values as zero and create an indicator column to mark the missing values
for col in df.columns:
    if df[col].dtype.name == 'float32':
        df[col + '_missing'] = df[col].isna().astype(int)
        df[col].fillna(0, inplace=True)

# %%
df.dtypes
# Out:
# id                                          Int32
# year                                        Int32
# cdp_orig_or_purchase_clean               category
# cdp_proj_type_clean                      category
# cdp_verification_clean                   category
# cdp_num_credits_clean                     float32
# cdp_num_credits_riskadj_clean             float32
# cdp_credits_cancelled_clean              category
# cdp_purpose_clean                        category
# cdp_num_credits_clean_missing               int64
# cdp_num_credits_riskadj_clean_missing       int64
# dtype: object

# %%
df.shape
# Out:
# (15348, 11)

# %%
# remove unusued categories for each category column
for col in df.columns:
    if df[col].dtype.name == 'category':
        df[col] = df[col].cat.remove_unused_categories()

# %%
# print the unique values for each column
for col in df.columns:
    print(col)
    print(df[col].unique())
    print('\n')
# Out:
# id
# <IntegerArray>
# [    53,     64,     79,     87,     97,    119,    135,    138,    143,
#     154,
#  ...
#  893445, 893453, 893701, 893848, 893859, 894762, 895062, 895100, 895218,
#  895519]
# Length: 1661, dtype: Int32
#
#
# year
# <IntegerArray>
# [2015, 2016, 2014, 2021, 2022, 2010, 2011, 2012, 2013, 2017, 2018, 2019, 2020]
# Length: 13, dtype: Int32
#
#
# cdp_orig_or_purchase_clean
# ['credit purchase', 'credit origination']
# Categories (2, object): ['credit origination', 'credit purchase']
#
#
# cdp_proj_type_clean
# ['biomass energy', 'other', 'forests', 'wind', 'methane avoidance', ..., 'fugitive', 'pfcs and sf6', 'hfcs', 'n2o', 'tidal']
# Length: 23
# Categories (23, object): ['agriculture', 'biomass energy', 'cement', 'co2 usage', ..., 'tidal', 'transport', 'wind', 'missing']
#
#
# cdp_verification_clean
# ['vcs (verified carbon standard)', 'not yet verified', 'gold standard', 'missing', 'cdm', ..., 'plan vivo', 'ji', 'car (the climate action reserve)', 'ccbs - climate, community & biodiversity stan..., 'ver+ (tv sd standard)']
# Length: 21
# Categories (21, object): ['acr (american carbon registry)', 'car', 'car (the climate action reserve)', 'ccbs (developed by the climate, community and..., ..., 'ver+', 'ver+ (tv sd standard)', 'ver+ (tÜv sÜd standard)', 'missing']
#
#
# cdp_num_credits_clean
# [  41.   40.    3. ...  792.  803. 2438.]
#
#
# cdp_num_credits_riskadj_clean
# [  41.   40.    0. ...  803. 2438. 4753.]
#
#
# cdp_credits_cancelled_clean
# ['yes', 'missing', 'no']
# Categories (3, object): ['no', 'yes', 'missing']
#
#
# cdp_purpose_clean
# ['voluntary offsetting', 'compliance', 'missing', 'other']
# Categories (4, object): ['compliance', 'other', 'voluntary offsetting', 'missing']
#
#
# cdp_num_credits_clean_missing
# [0 1]
#
#
# cdp_num_credits_riskadj_clean_missing
# [0 1]

# %%
# dropping proj_type and cdp_verification_clean
df.drop(columns=['cdp_verification_clean', 'cdp_proj_type_clean'], inplace=True)

# %% [markdown]
# ## Data Transformation Summary
#
# This notebook section performs data preparation suitable for predictive modeling, with a focus on training an LSTM model. The dataset originates from carbon credit purchase records, detailing transactions by firms across various years. Our predictive target is to forecast the `real_ghg_change`, representing the actual change in greenhouse gas emissions.
#
# ### Transformations applied are as follows:
#
# 1. **Binary Variables Creation**: For each categorical attribute, binary (dummy) variables are generated. This process transforms the categorical data into a set of binary features where each feature signifies the presence (1) or absence (0) of a category for each firm-year instance.
#
# 2. **Numerical Summary Statistics**: Summary statistics (sum, mean, median, max, and min) are calculated for the total number of carbon credits before and after risk adjustment (`cdp_num_credits_clean` and `cdp_num_credits_riskadj_clean`). These aggregated metrics offer a nuanced view of credit purchase activities per firm per annum.
#
# 3. **Grouping and Aggregation**: The dataset is grouped by `id` and `year`, and the aforementioned binary and numerical attributes are aggregated accordingly. This step ensures a single composite row per firm-year pairing, aligning with the structure requisite for LSTM and other time-series analysis methodologies.
#
# 4. **Final Dataset Assembly**: The aggregated binary features are combined with the numerical summary statistics to compose the final dataset. Structured with a multi-index of firm ID and year, this dataset is well-suited for panel data analysis and subsequent modeling tasks.
#
# The resulting DataFrame is a comprehensive feature matrix, melding transformed categorical data with aggregated numerical data, primed for deployment in machine learning models aiming to predict changes in greenhouse gas emissions.

# %% [markdown]
# ## Rationale for Retaining Missingness Indicators
#
# In the transformed dataset, we have chosen to retain both 'True' and 'False' missingness indicator columns for each type of credit number—`cdp_num_credits_clean` and `cdp_num_credits_riskadj_clean`. This decision is rooted in the aim to preserve the full extent of information on data completeness post-aggregation. The 'True' columns provide the count of missing entries, while the 'False' columns inform us about the count of non-missing entries for each firm-year combination. As we do not have a separate record of the total number of observations for each firm-year grouping before aggregation, maintaining these columns becomes crucial. They serve as a dual record that not only informs about the presence of missing values but also implicitly indicates the volume of reported data, thus acting as a proxy for the original number of observations. This information is valuable for predictive modeling as it allows the model to account for data completeness and potential patterns in missingness, which may contribute to more accurate predictions.

# %%
df.describe()
# Out:
#                   id         year  cdp_num_credits_clean  \
# count        15348.0      15348.0           1.534800e+04
# mean    33666.903701  2016.729541           1.516548e+05
# std    124789.505796     3.839488           1.080667e+06
# min             53.0       2010.0           0.000000e+00
# 25%           4663.0       2013.0           8.333300e+02
# 50%          12860.0       2017.0           8.049000e+03
# 75%          19792.5       2020.0           4.617750e+04
# max         895519.0       2022.0           7.113400e+07
#
#        cdp_num_credits_riskadj_clean  cdp_num_credits_clean_missing  \
# count                   1.534800e+04                   15348.000000
# mean                    1.075957e+05                       0.043589
# std                     9.335071e+05                       0.204185
# min                     0.000000e+00                       0.000000
# 25%                     0.000000e+00                       0.000000
# 50%                     2.053500e+03                       0.000000
# 75%                     2.500000e+04                       0.000000
# max                     7.113400e+07                       1.000000
#
#        cdp_num_credits_riskadj_clean_missing
# count                           15348.000000
# mean                                0.209017
# std                                 0.406620
# min                                 0.000000
# 25%                                 0.000000
# 50%                                 0.000000
# 75%                                 0.000000
# max                                 1.000000

# %%
# Create binary variables for each categorical column
categorical_columns = ['cdp_orig_or_purchase_clean', 'cdp_credits_cancelled_clean','cdp_purpose_clean']
df_dummies = pd.get_dummies(df[categorical_columns])

# Define the aggregations for numerical columns
aggregations = {
    'cdp_num_credits_clean': ['sum', 'count'],
    'cdp_num_credits_riskadj_clean': ['sum'],
    'cdp_num_credits_clean_missing': ['sum'],
    'cdp_num_credits_riskadj_clean_missing': ['sum'],
}

# Group by 'id' and 'year', then aggregate
df_grouped = df.groupby(['id', 'year']).agg(aggregations)

# Flatten the MultiIndex for columns created by groupby aggregation
df_grouped.columns = ['_'.join(col).strip() for col in df_grouped.columns.values]

# Group the binary variables by 'id' and 'year', and sum them to get the count of each category
df_dummies_grouped = df_dummies.groupby([df['id'], df['year']]).sum()

# Join the binary variables with the grouped numerical data
# Make sure indices are sorted before joining if they aren't already
df_final = df_grouped.join(df_dummies_grouped, how='left').reset_index()


# Now df_final is ready for further analysis or modeling

# %%
categorical_columns
# Out:
# ['cdp_orig_or_purchase_clean',
#  'cdp_credits_cancelled_clean',
#  'cdp_purpose_clean']

# %%
# check unique id, year pairs
df_final.groupby(['id', 'year']).size().shape
# Out:
# (5784,)

# %%
df_final.shape
# Out:
# (5784, 16)

# %%
df_final.isna().sum()
# Out:
# id                                               0
# year                                             0
# cdp_num_credits_clean_sum                        0
# cdp_num_credits_clean_count                      0
# cdp_num_credits_riskadj_clean_sum                0
# cdp_num_credits_clean_missing_sum                0
# cdp_num_credits_riskadj_clean_missing_sum        0
# cdp_orig_or_purchase_clean_credit origination    0
# cdp_orig_or_purchase_clean_credit purchase       0
# cdp_credits_cancelled_clean_no                   0
# cdp_credits_cancelled_clean_yes                  0
# cdp_credits_cancelled_clean_missing              0
# cdp_purpose_clean_compliance                     0
# cdp_purpose_clean_other                          0
# cdp_purpose_clean_voluntary offsetting           0
# cdp_purpose_clean_missing                        0
# dtype: int64

# %%
df_final.head()
# Out:
#    id  year  cdp_num_credits_clean_sum  cdp_num_credits_clean_count  \
# 0  53  2015                       41.0                            1
# 1  53  2016                       40.0                            1
# 2  64  2014                        3.0                            1
# 3  79  2021                    20140.0                            3
# 4  79  2022                    20438.0                            5
#
#    cdp_num_credits_riskadj_clean_sum  cdp_num_credits_clean_missing_sum  \
# 0                               41.0                                  0
# 1                               40.0                                  0
# 2                                0.0                                  0
# 3                                0.0                                  0
# 4                            20438.0                                  0
#
#    cdp_num_credits_riskadj_clean_missing_sum  \
# 0                                          0
# 1                                          0
# 2                                          0
# 3                                          2
# 4                                          0
#
#    cdp_orig_or_purchase_clean_credit origination  \
# 0                                              0
# 1                                              0
# 2                                              0
# 3                                              0
# 4                                              0
#
#    cdp_orig_or_purchase_clean_credit purchase  cdp_credits_cancelled_clean_no  \
# 0                                           1                               0
# 1                                           1                               0
# 2                                           1                               0
# 3                                           3                               0
# 4                                           5                               0
#
#    cdp_credits_cancelled_clean_yes  cdp_credits_cancelled_clean_missing  \
# 0                                1                                    0
# 1                                1                                    0
# 2                                1                                    0
# 3                                3                                    0
# 4                                5                                    0
#
#    cdp_purpose_clean_compliance  cdp_purpose_clean_other  \
# 0                             0                        0
# 1                             0                        0
# 2                             1                        0
# 3                             0                        0
# 4                             0                        0
#
#    cdp_purpose_clean_voluntary offsetting  cdp_purpose_clean_missing
# 0                                       1                          0
# 1                                       1                          0
# 2                                       0                          0
# 3                                       3                          0
# 4                                       5                          0

# %% [markdown]
# **I am taking the log1p of the numerical variables as they look skewed.**

# %%
# log1p all the cdp_num_credits_clean
df_final['cdp_num_credits_clean_sum'] = np.log1p(df_final['cdp_num_credits_clean_sum'])

# log1p all the cdp_num_credits_riskadj_clean
df_final['cdp_num_credits_riskadj_clean_sum'] = np.log1p(df_final['cdp_num_credits_riskadj_clean_sum'])

# %%
df_final.describe()
# Out:
#                   id         year  cdp_num_credits_clean_sum  \
# count         5784.0       5784.0                5784.000000
# mean    45941.104772  2017.308956                   8.906804
# std    154398.856698     3.777004                   3.674026
# min             53.0       2010.0                   0.000000
# 25%           5634.0       2014.0                   6.980308
# 50%          14526.0       2018.0                   9.403383
# 75%          21537.0       2021.0                  11.456654
# max         895519.0       2022.0                  18.290958
#
#        cdp_num_credits_clean_count  cdp_num_credits_riskadj_clean_sum  \
# count                  5784.000000                        5784.000000
# mean                      2.653527                           6.695766
# std                       4.433919                           4.982852
# min                       1.000000                           0.000000
# 25%                       1.000000                           0.000000
# 50%                       1.000000                           7.881182
# 75%                       3.000000                          10.747437
# max                      98.000000                          18.290958
#
#        cdp_num_credits_clean_missing_sum  \
# count                        5784.000000
# mean                            0.115664
# std                             0.881695
# min                             0.000000
# 25%                             0.000000
# 50%                             0.000000
# 75%                             0.000000
# max                            28.000000
#
#        cdp_num_credits_riskadj_clean_missing_sum  \
# count                                5784.000000
# mean                                    0.554633
# std                                     2.592329
# min                                     0.000000
# 25%                                     0.000000
# 50%                                     0.000000
# 75%                                     0.000000
# max                                    72.000000
#
#        cdp_orig_or_purchase_clean_credit origination  \
# count                                    5784.000000
# mean                                        0.692254
# std                                         2.588707
# min                                         0.000000
# 25%                                         0.000000
# 50%                                         0.000000
# 75%                                         1.000000
# max                                        97.000000
#
#        cdp_orig_or_purchase_clean_credit purchase  \
# count                                 5784.000000
# mean                                     1.961272
# std                                      3.559463
# min                                      0.000000
# 25%                                      1.000000
# 50%                                      1.000000
# 75%                                      2.000000
# max                                     57.000000
#
#        cdp_credits_cancelled_clean_no  cdp_credits_cancelled_clean_yes  \
# count                     5784.000000                      5784.000000
# mean                         0.689834                         1.372925
# std                          2.203450                         3.157095
# min                          0.000000                         0.000000
# 25%                          0.000000                         0.000000
# 50%                          0.000000                         1.000000
# 75%                          1.000000                         1.000000
# max                         54.000000                        68.000000
#
#        cdp_credits_cancelled_clean_missing  cdp_purpose_clean_compliance  \
# count                          5784.000000                   5784.000000
# mean                              0.590768                      0.602006
# std                               2.706342                      3.834322
# min                               0.000000                      0.000000
# 25%                               0.000000                      0.000000
# 50%                               0.000000                      0.000000
# 75%                               1.000000                      0.000000
# max                              96.000000                     98.000000
#
#        cdp_purpose_clean_other  cdp_purpose_clean_voluntary offsetting  \
# count              5784.000000                             5784.000000
# mean                  0.142808                                1.767981
# std                   0.778631                                2.534173
# min                   0.000000                                0.000000
# 25%                   0.000000                                1.000000
# 50%                   0.000000                                1.000000
# 75%                   0.000000                                2.000000
# max                  20.000000                               42.000000
#
#        cdp_purpose_clean_missing
# count                5784.000000
# mean                    0.140733
# std                     0.718983
# min                     0.000000
# 25%                     0.000000
# 50%                     0.000000
# 75%                     0.000000
# max                    11.000000

# %%
# save the df final to csv in the processed data folder
df_final.to_csv('../../data/processed/cdp_carbon_credits_full_processed.csv', index=False)

# %%
df_final.shape
# Out:
# (5784, 16)

# %%
df.columns
# Out:
# Index(['id', 'year', 'cdp_orig_or_purchase_clean', 'cdp_num_credits_clean',
#        'cdp_num_credits_riskadj_clean', 'cdp_credits_cancelled_clean',
#        'cdp_purpose_clean', 'cdp_num_credits_clean_missing',
#        'cdp_num_credits_riskadj_clean_missing'],
#       dtype='object')

# %%
# jetblue sanity check - seems to be fine
df_final.loc[df_final['id'] == 9759]
# Out:
#         id  year  cdp_num_credits_clean_sum  cdp_num_credits_clean_count  \
# 2114  9759  2018                   4.194341                            1
# 2115  9759  2019                   4.194341                            1
# 2116  9759  2020                  12.524282                            2
# 2117  9759  2021                  14.136120                            1
# 2118  9759  2022                   0.000000                            1
#
#       cdp_num_credits_riskadj_clean_sum  cdp_num_credits_clean_missing_sum  \
# 2114                           4.194341                                  0
# 2115                           4.194341                                  0
# 2116                           0.000000                                  0
# 2117                           0.000000                                  0
# 2118                           0.000000                                  1
#
#       cdp_num_credits_riskadj_clean_missing_sum  \
# 2114                                          0
# 2115                                          0
# 2116                                          2
# 2117                                          1
# 2118                                          1
#
#       cdp_orig_or_purchase_clean_credit origination  \
# 2114                                              0
# 2115                                              0
# 2116                                              0
# 2117                                              0
# 2118                                              0
#
#       cdp_orig_or_purchase_clean_credit purchase  \
# 2114                                           1
# 2115                                           1
# 2116                                           2
# 2117                                           1
# 2118                                           1
#
#       cdp_credits_cancelled_clean_no  cdp_credits_cancelled_clean_yes  \
# 2114                               0                                0
# 2115                               0                                1
# 2116                               0                                2
# 2117                               0                                0
# 2118                               0                                1
#
#       cdp_credits_cancelled_clean_missing  cdp_purpose_clean_compliance  \
# 2114                                    1                             0
# 2115                                    0                             0
# 2116                                    0                             0
# 2117                                    1                             0
# 2118                                    0                             0
#
#       cdp_purpose_clean_other  cdp_purpose_clean_voluntary offsetting  \
# 2114                        0                                       1
# 2115                        0                                       1
# 2116                        0                                       2
# 2117                        0                                       1
# 2118                        0                                       1
#
#       cdp_purpose_clean_missing
# 2114                          0
# 2115                          0
# 2116                          0
# 2117                          0
# 2118                          0

# %% [markdown]
# # Test Join with Id Year Isin Mapping

# %%
# read the mapping 
mapping = pd.read_csv("../../data/processed/id_year_isin_mapping.csv", index_col=['id', 'year'])

# %%
mapping.shape
# Out:
# (24302, 1)

# %%
df_final.set_index(['id','year'], inplace=True)

# %%
df_mapped = mapping.join(df_final, on=['id', 'year']).reset_index()

# %%
df_mapped['absent_cdp_carbon_credits_full'] = (df_mapped.isna().sum(axis=1) > 0 ).astype(int)

# %%
df_mapped.replace(np.nan, 0, inplace=True)

# %%
df_mapped.sample(10)
# Out:
#           id    year          isin  cdp_num_credits_clean_sum  \
# 7381    8698  2016.0  ES0144580Y14                  12.274418
# 1738    1356  2018.0  US05722G1004                   0.000000
# 16827  20754  2021.0  ZAE000009932                   0.000000
# 16686  20612  2019.0  US9621661043                   0.000000
# 16467  20363  2015.0  DE000WCH8881                   0.000000
# 3879    3795  2019.0  US21036P1084                   5.422215
# 18661  22684  2011.0  ZAE000117321                   0.000000
# 13684  16737  2017.0  JP3105220002                   0.000000
# 23487  74117  2021.0  GB00BYT18307                   0.000000
# 17517  21419  2018.0  MYL6888OO001                   0.000000
#
#        cdp_num_credits_clean_count  cdp_num_credits_riskadj_clean_sum  \
# 7381                          11.0                          12.274413
# 1738                           0.0                           0.000000
# 16827                          0.0                           0.000000
# 16686                          0.0                           0.000000
# 16467                          0.0                           0.000000
# 3879                           1.0                           5.422215
# 18661                          0.0                           0.000000
# 13684                          0.0                           0.000000
# 23487                          0.0                           0.000000
# 17517                          0.0                           0.000000
#
#        cdp_num_credits_clean_missing_sum  \
# 7381                                 0.0
# 1738                                 0.0
# 16827                                0.0
# 16686                                0.0
# 16467                                0.0
# 3879                                 0.0
# 18661                                0.0
# 13684                                0.0
# 23487                                0.0
# 17517                                0.0
#
#        cdp_num_credits_riskadj_clean_missing_sum  \
# 7381                                         0.0
# 1738                                         0.0
# 16827                                        0.0
# 16686                                        0.0
# 16467                                        0.0
# 3879                                         0.0
# 18661                                        0.0
# 13684                                        0.0
# 23487                                        0.0
# 17517                                        0.0
#
#        cdp_orig_or_purchase_clean_credit origination  \
# 7381                                             0.0
# 1738                                             0.0
# 16827                                            0.0
# 16686                                            0.0
# 16467                                            0.0
# 3879                                             0.0
# 18661                                            0.0
# 13684                                            0.0
# 23487                                            0.0
# 17517                                            0.0
#
#        cdp_orig_or_purchase_clean_credit purchase  \
# 7381                                         11.0
# 1738                                          0.0
# 16827                                         0.0
# 16686                                         0.0
# 16467                                         0.0
# 3879                                          1.0
# 18661                                         0.0
# 13684                                         0.0
# 23487                                         0.0
# 17517                                         0.0
#
#        cdp_credits_cancelled_clean_no  cdp_credits_cancelled_clean_yes  \
# 7381                              0.0                             11.0
# 1738                              0.0                              0.0
# 16827                             0.0                              0.0
# 16686                             0.0                              0.0
# 16467                             0.0                              0.0
# 3879                              0.0                              1.0
# 18661                             0.0                              0.0
# 13684                             0.0                              0.0
# 23487                             0.0                              0.0
# 17517                             0.0                              0.0
#
#        cdp_credits_cancelled_clean_missing  cdp_purpose_clean_compliance  \
# 7381                                   0.0                          10.0
# 1738                                   0.0                           0.0
# 16827                                  0.0                           0.0
# 16686                                  0.0                           0.0
# 16467                                  0.0                           0.0
# 3879                                   0.0                           0.0
# 18661                                  0.0                           0.0
# 13684                                  0.0                           0.0
# 23487                                  0.0                           0.0
# 17517                                  0.0                           0.0
#
#        cdp_purpose_clean_other  cdp_purpose_clean_voluntary offsetting  \
# 7381                       0.0                                     1.0
# 1738                       0.0                                     0.0
# 16827                      0.0                                     0.0
# 16686                      0.0                                     0.0
# 16467                      0.0                                     0.0
# 3879                       0.0                                     1.0
# 18661                      0.0                                     0.0
# 13684                      0.0                                     0.0
# 23487                      0.0                                     0.0
# 17517                      0.0                                     0.0
#
#        cdp_purpose_clean_missing  absent_cdp_carbon_credits_full
# 7381                         0.0                               0
# 1738                         0.0                               1
# 16827                        0.0                               1
# 16686                        0.0                               1
# 16467                        0.0                               1
# 3879                         0.0                               0
# 18661                        0.0                               1
# 13684                        0.0                               1
# 23487                        0.0                               1
# 17517                        0.0                               1

# %%
df_mapped.shape
# Out:
# (24302, 18)
